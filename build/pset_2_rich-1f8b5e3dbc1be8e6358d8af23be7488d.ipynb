# %% [markdown]
# ---
# numbering:
#   headings: false
# downloads:
#   -
#     title: pset_2.ipynb
#     url: ../../assets/downloads/problem_sets/pset_2.ipynb
#     filename: pset_2.ipynb
# ---
#
# (sec:pset_2)=
#
# # Problem Set 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# :::{warning} Under construction
# The Problem Set 2 is currently being prepared and will be made available soon.
# :::

# %% [markdown]
# ## Exercise 2.1: The Hückel Method
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
