# %% [markdown]
# ---
# numbering:
#   headings: false
# ---
#
# (sec:project_template)=
#
# # Template
#
# Download this template with the download icon in the top-right corner, then replace `# Template` with your project title.
#
# ## Background
#
# Briefly introduce the problem your project addresses and explain how it connects to the course content, for example {ref}`sec:root_finding`. Include any equations, diagrams, or context needed to make the project understandable.
#
# ![](/assets/figures/numerical_foundations/epoxyoctene.svg)
#
# ## Assets
#
# If your project uses data, provide it here as a downloadable CSV file, for example {download}`/assets/data/numerical_foundations/mn_decay_20.csv`.
#
# ## Implementation
#
# Use the code cells below to implement your solution. Add concise comments where they help explain important steps in your code.

# %%
# Imports

# %%
# Your code

# %%
# Your code

# %%
# Your code

# %% [markdown]
# ## Results
#
# Summarise your main results in a few sentences and interpret what they show.
#
# ## Further Questions
#
# Discuss possible extensions of your project, as well as any limitations or open problems you could not resolve.
